# %%
#ocr(광학문자 판독)

-Tessaract API, 구글 OCR API, NAVER OCR API 등을 사용
-https://github.com/UB-Mannheim/tesseract/wiki
-설치시에 Additional language data 체크

# %%
pip install pytesseract

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('text.jpg')
img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)

gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

_,binary = cv2.threshold(gray,180,255,cv2.THRESH_BINARY)

plt.xticks([])
plt.yticks([])
plt.imshow(img)

#이미지에서 문자열을 추출 (한글이면 kor) 
result = pytesseract.image_to_string(binary,lang='kor')

print(result)
# Out:
# 오귀썬부터 금씨를 많이 쓰는 사부싶어서 인해은
# 강 부장입시다, 사부싶어서 흔히 볼 수 있는 이
# 금씨로 타0똥하모면 어떻7요?

# %%
##Tesseract API 사용할때는 이전 이미지로 변경한 후 사용하는 것을 권장
